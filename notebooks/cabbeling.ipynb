# %% [markdown]
# # Cabbeling simulation
#
# Convection driven by density gradients appearing because of the mixing of
# cold and hot water at the same denisty. This is cause by the nonlinearity of the equation of state of water.
# We start with a stable fluid, with hot water (7.55ᵒ C) above cold water (1ᵒ C).
# The fluid is initially at rest because the density is constant in the domain, but mixing of cold and hot water
# generates temperatures that correspond to higher density (the maximum density of fresh water is at 4ᵒ C) and
# the mixed water starts to sink.

# %%
using Pkg
pkg"add ClimaOcean Oceananigans#ss/for-drakkar, SeawaterPolynomials, CairoMakie, FileIO"

using Oceananigans
using Oceananigans.Models: seawater_density
using SeawaterPolynomials: TEOS10EquationOfState
# Out:
#      Cloning git-repo `https://github.com/CliMA/Oceananigans.jl.git`
# git-repo `https://github.com/CliMA/Oceananigans.jl.git`
#     Updating registry at `~/.julia/registries/General.toml`
# package versions...ng
#    Installed AxisArrays ─────────────────────── v0.4.7
#    Installed JpegTurbo_jll ──────────────────── v3.1.1+0
#    Installed x265_jll ───────────────────────── v3.6.0+0
#    Installed libfdk_aac_jll ─────────────────── v2.0.3+0
#    Installed ImageIO ────────────────────────── v0.6.9
#    Installed TiffImages ─────────────────────── v0.11.2
#    Installed OffsetArrays ───────────────────── v1.15.0
#    Installed ClimaOcean ─────────────────────── v0.3.3
#    Installed TiledIteration ─────────────────── v0.5.0
#    Installed Libmount_jll ───────────────────── v2.40.3+0
#    Installed HypergeometricFunctions ────────── v0.3.25
#    Installed PNGFiles ───────────────────────── v0.4.3
#    Installed JpegTurbo ──────────────────────── v0.1.5
#    Installed LERC_jll ───────────────────────── v4.0.1+0
#    Installed LRUCache ───────────────────────── v1.6.1
#    Installed AdaptivePredicates ─────────────── v1.2.0
#    Installed Accessors ──────────────────────── v0.1.41
#    Installed LoggingExtras ──────────────────── v1.1.0
#    Installed StatsFuns ──────────────────────── v1.3.2
#    Installed FFTW ───────────────────────────── v1.8.0
#    Installed TaylorSeries ───────────────────── v0.18.2
#    Installed Opus_jll ───────────────────────── v1.3.3+0
#    Installed LLVMLoopInfo ───────────────────── v1.0.0
#    Installed RelocatableFolders ─────────────── v1.0.1
#    Installed Unitful ────────────────────────── v1.22.0
#    Installed TimerOutputs ───────────────────── v0.5.26
#    Installed PDMats ─────────────────────────── v0.11.32
#    Installed Sixel ──────────────────────────── v0.1.3
#    Installed StaticArrays ───────────────────── v1.9.10
#    Installed ConcurrentUtilities ────────────── v2.4.3
#    Installed Contour ────────────────────────── v0.6.3
#    Installed InlineStrings ──────────────────── v1.4.2
#    Installed SetRounding ────────────────────── v0.2.1
#    Installed ProgressMeter ──────────────────── v1.10.2
#    Installed EarCut_jll ─────────────────────── v2.2.4+0
#    Installed CubedSphere ────────────────────── v0.3.1
#    Installed Grisu ──────────────────────────── v1.0.2
#    Installed OpenEXR ────────────────────────── v0.3.3
#    Installed Roots ──────────────────────────── v2.2.4
#    Installed ColorSchemes ───────────────────── v3.28.0
#    Installed PlotUtils ──────────────────────── v1.4.3
#    Installed NVTX_jll ───────────────────────── v3.1.0+2
#    Installed EnumX ──────────────────────────── v1.0.4
#    Installed CEnum ──────────────────────────── v0.5.0
#    Installed Xorg_libpthread_stubs_jll ──────── v0.1.2+0
#    Installed OpenSSL ────────────────────────── v1.4.3
#    Installed Thermodynamics ─────────────────── v0.12.9
#    Installed FileIO ─────────────────────────── v1.16.6
#    Installed HTTP ───────────────────────────── v1.10.15
#    Installed InvertedIndices ────────────────── v1.3.1
#    Installed GPUArrays ──────────────────────── v10.3.1
#    Installed BFloat16s ──────────────────────── v0.5.0
#    Installed Cairo_jll ──────────────────────── v1.18.2+1
#    Installed Fontconfig_jll ─────────────────── v2.15.0+0
#    Installed CUDA_Runtime_jll ───────────────── v0.15.5+0
#    Installed Statistics ─────────────────────── v1.11.1
#    Installed Libgpg_error_jll ───────────────── v1.51.1+0
#    Installed RandomNumbers ──────────────────── v1.6.0
#    Installed DataFrames ─────────────────────── v1.7.0
#    Installed IntelOpenMP_jll ────────────────── v2024.2.1+0
#    Installed Netpbm ─────────────────────────── v1.1.1
#    Installed SignedDistanceFields ───────────── v0.4.0
#    Installed SLEEFPirates ───────────────────── v0.6.43
#    Installed CFTime ─────────────────────────── v0.1.4
#    Installed FastRounding ───────────────────── v0.3.1
#    Installed FilePaths ──────────────────────── v0.8.3
#    Installed Xorg_libXau_jll ────────────────── v1.0.12+0
#    Installed Static ─────────────────────────── v1.1.1
#    Installed Distances ──────────────────────── v0.10.12
#    Installed RoundingEmulator ───────────────── v0.2.1
#    Installed Missings ───────────────────────── v1.2.0
#    Installed LLVM ───────────────────────────── v9.1.3
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed JLD2 ───────────────────────────── v0.5.11
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed IncompleteLU ───────────────────── v0.2.1
#    Installed IrrationalConstants ────────────── v0.2.2
#    Installed SIMD ───────────────────────────── v3.7.1
#    Installed TriplotBase ────────────────────── v0.1.0
#    Installed Showoff ────────────────────────── v1.0.3
#    Installed Giflib_jll ─────────────────────── v5.2.3+0
#    Installed demumble_jll ───────────────────── v1.3.0+0
#    Installed Pango_jll ──────────────────────── v1.55.5+0
#    Installed PolygonOps ─────────────────────── v0.1.2
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed SurfaceFluxes ──────────────────── v0.12.0
#    Installed PtrArrays ──────────────────────── v1.3.0
#    Installed MathTeXEngine ──────────────────── v0.6.2
#    Installed RootSolvers ────────────────────── v0.4.2
#    Installed CUDA_Driver_jll ────────────────── v0.10.4+0
#    Installed Hwloc_jll ──────────────────────── v2.11.2+3
#    Installed SpecialFunctions ───────────────── v2.5.0
#    Installed Bzip2_jll ──────────────────────── v1.0.8+4
#    Installed QOI ────────────────────────────── v1.0.1
#    Installed SimpleBufferStream ─────────────── v1.2.0
#    Installed SentinelArrays ─────────────────── v1.4.8
#    Installed XZ_jll ─────────────────────────── v5.6.4+0
#    Installed HarfBuzz_jll ───────────────────── v8.5.0+0
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed isoband_jll ────────────────────── v0.2.3+0
#    Installed PkgVersion ─────────────────────── v0.3.3
#    Installed MicrosoftMPI_jll ───────────────── v10.1.4+3
#    Installed Literate ───────────────────────── v2.20.1
#    Installed StaticArraysCore ───────────────── v1.4.3
#    Installed NaNMath ────────────────────────── v1.0.3
#    Installed CUDA_Runtime_Discovery ─────────── v0.3.5
#    Installed LZO_jll ────────────────────────── v2.10.3+0
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed WebP ───────────────────────────── v0.1.3
#    Installed TranscodingStreams ─────────────── v0.11.3
#    Installed FriBidi_jll ────────────────────── v1.0.16+0
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed UnicodeFun ─────────────────────── v0.4.1
#    Installed Random123 ──────────────────────── v1.7.0
#    Installed MPIPreferences ─────────────────── v0.1.11
#    Installed Graphics ───────────────────────── v1.1.3
#    Installed Lz4_jll ────────────────────────── v1.10.1+0
#    Installed Rmath_jll ──────────────────────── v0.5.1+0
#    Installed ImageMetadata ──────────────────── v0.9.10
#    Installed Ratios ─────────────────────────── v0.4.5
#    Installed x264_jll ───────────────────────── v10164.0.1+0
#    Installed DataStructures ─────────────────── v0.18.20
#    Installed Colors ─────────────────────────── v0.13.0
#    Installed PaddedViews ────────────────────── v0.5.12
#    Installed CommonSubexpressions ───────────── v0.3.1
#    Installed FreeType2_jll ──────────────────── v2.13.3+1
#    Installed MappedArrays ───────────────────── v0.4.2
#    Installed FreeType ───────────────────────── v4.1.1
#    Installed ExprTools ──────────────────────── v0.1.10
#    Installed StatsAPI ───────────────────────── v1.7.0
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed NetCDF_jll ─────────────────────── v400.902.209+0
#    Installed GridLayoutBase ─────────────────── v0.11.1
#    Installed ClimaSeaIce ────────────────────── v0.1.4
#    Installed Compat ─────────────────────────── v4.16.0
#    Installed Automa ─────────────────────────── v1.1.0
#    Installed StaticArrayInterface ───────────── v1.8.0
#    Installed Glob ───────────────────────────── v1.3.1
#    Installed HDF5_jll ───────────────────────── v1.14.2+1
#    Installed LazyModules ────────────────────── v0.3.1
#    Installed StatsBase ──────────────────────── v0.34.4
#    Installed Xorg_libxcb_jll ────────────────── v1.17.0+3
#    Installed libpng_jll ─────────────────────── v1.6.45+1
#    Installed MosaicViews ────────────────────── v0.3.4
#    Installed ExceptionUnwrapping ────────────── v0.1.11
#    Installed CodecZlib ──────────────────────── v0.7.6
#    Installed libaom_jll ─────────────────────── v3.11.0+0
#    Installed MPICH_jll ──────────────────────── v4.2.3+0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed Scratch ────────────────────────── v1.2.1
#    Installed ImageCore ──────────────────────── v0.10.5
#    Installed oneTBB_jll ─────────────────────── v2021.12.0+0
#    Installed ColorTypes ─────────────────────── v0.12.0
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed libzip_jll ─────────────────────── v1.11.2+2
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed Xorg_libXext_jll ───────────────── v1.3.6+3
#    Installed TensorCore ─────────────────────── v0.1.1
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed FreeTypeAbstraction ────────────── v0.10.6
#    Installed Zstd_jll ───────────────────────── v1.5.7+0
#    Installed PrettyTables ───────────────────── v2.4.0
#    Installed Expat_jll ──────────────────────── v2.6.4+3
#    Installed Isoband ────────────────────────── v0.1.1
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed Imath_jll ──────────────────────── v3.1.11+0
#    Installed Inflate ────────────────────────── v0.1.5
#    Installed DataDeps ───────────────────────── v0.7.13
#    Installed Extents ────────────────────────── v0.1.5
#    Installed OpenMPI_jll ────────────────────── v5.0.6+0
#    Installed MKL_jll ────────────────────────── v2024.2.0+0
#    Installed LoopVectorization ──────────────── v0.12.171
#    Installed PooledArrays ───────────────────── v1.4.3
#    Installed OrthogonalSphericalShellGrids ──── v0.2.1
#    Installed Animations ─────────────────────── v0.4.2
#    Installed Format ─────────────────────────── v1.3.7
#    Installed AbstractFFTs ───────────────────── v1.5.0
#    Installed Libtiff_jll ────────────────────── v4.7.1+0
#    Installed Packing ────────────────────────── v0.5.1
#    Installed ConstructionBase ───────────────── v1.5.8
#    Installed NVTX ───────────────────────────── v0.3.5
#    Installed LLVMExtra_jll ──────────────────── v0.0.34+0
#    Installed ColorVectorSpace ───────────────── v0.11.0
#    Installed OrderedCollections ─────────────── v1.7.0
#    Installed AbstractTrees ──────────────────── v0.4.5
#    Installed Libffi_jll ─────────────────────── v3.2.2+2
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed Xorg_libXrender_jll ────────────── v0.9.11+1
#    Installed Ogg_jll ────────────────────────── v1.3.5+1
#    Installed KernelDensity ──────────────────── v0.6.9
#    Installed ExactPredicates ────────────────── v2.2.5
#    Installed NCDatasets ─────────────────────── v0.14.6
#    Installed ChainRulesCore ─────────────────── v1.25.1
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed Interpolations ─────────────────── v0.15.1
#    Installed ArrayInterface ─────────────────── v7.18.0
#    Installed XSLT_jll ───────────────────────── v1.1.42+0
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed SeawaterPolynomials ────────────── v0.3.5
#    Installed CommonDataModel ────────────────── v0.3.7
#    Installed Quaternions ────────────────────── v0.7.6
#    Installed IntervalArithmetic ─────────────── v0.20.9
#    Installed LogExpFunctions ────────────────── v0.3.29
#    Installed KernelAbstractions ─────────────── v0.9.32
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed AliasTables ────────────────────── v1.1.3
#    Installed StackViews ─────────────────────── v0.1.1
#    Installed MacroTools ─────────────────────── v0.5.15
#    Installed Rotations ──────────────────────── v1.7.1
#    Installed FFTW_jll ───────────────────────── v3.3.10+3
#    Installed RangeArrays ────────────────────── v0.3.2
#    Installed CompositionsBase ───────────────── v0.1.2
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed OpenSpecFun_jll ────────────────── v0.5.6+0
#    Installed UnsafeAtomics ──────────────────── v0.3.0
#    Installed GeoFormatTypes ─────────────────── v0.4.4
#    Installed CommonSolve ────────────────────── v0.2.4
#    Installed InverseFunctions ───────────────── v0.1.17
#    Installed Libuuid_jll ────────────────────── v2.40.3+0
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed Atomix ─────────────────────────── v1.0.1
#    Installed ColorBrewer ────────────────────── v0.4.1
#    Installed DocStringExtensions ────────────── v0.9.3
#    Installed OpenEXR_jll ────────────────────── v3.2.4+0
#    Installed GPUArraysCore ──────────────────── v0.1.6
#    Installed Blosc_jll ──────────────────────── v1.21.6+2
#    Installed libaec_jll ─────────────────────── v1.1.3+0
#    Installed Adapt ──────────────────────────── v4.1.1
#    Installed Crayons ────────────────────────── v4.1.1
#    Installed StableRNGs ─────────────────────── v1.0.2
#    Installed Graphite2_jll ──────────────────── v1.3.14+1
#    Installed Pixman_jll ─────────────────────── v0.43.4+0
#    Installed libass_jll ─────────────────────── v0.15.2+0
#    Installed VectorizationBase ──────────────── v0.21.71
#    Installed XML2_jll ───────────────────────── v2.13.5+0
#    Installed Rmath ──────────────────────────── v0.8.0
#    Installed ImageBase ──────────────────────── v0.1.7
#    Installed Gettext_jll ────────────────────── v0.21.0+0
#    Installed Suppressor ─────────────────────── v0.2.8
#    Installed IntervalSets ───────────────────── v0.7.10
#    Installed Cairo ──────────────────────────── v1.1.1
#    Installed Xorg_xtrans_jll ────────────────── v1.5.1+0
#    Installed IterTools ──────────────────────── v1.10.0
#    Installed MPI ────────────────────────────── v0.20.22
#    Installed OpenSSL_jll ────────────────────── v3.0.15+3
#    Installed GPUCompiler ────────────────────── v0.27.8
#    Installed BitFlags ───────────────────────── v0.1.9
#    Installed IndirectArrays ─────────────────── v1.0.0
#    Installed GeometryBasics ─────────────────── v0.5.1
#    Installed FFMPEG_jll ─────────────────────── v6.1.2+0
#    Installed IOCapture ──────────────────────── v0.2.5
#    Installed Libgcrypt_jll ──────────────────── v1.11.0+0
#    Installed CPUSummary ─────────────────────── v0.2.6
#    Installed Tables ─────────────────────────── v1.12.0
#    Installed MakieCore ──────────────────────── v0.9.0
#    Installed DataAPI ────────────────────────── v1.16.0
#    Installed LLVMOpenMP_jll ─────────────────── v18.1.7+0
#    Installed CairoMakie ─────────────────────── v0.13.0
#    Installed FixedPointNumbers ──────────────── v0.8.5
#    Installed ShaderAbstractions ─────────────── v0.5.0
#    Installed RecipesBase ────────────────────── v1.3.4
#    Installed LAME_jll ───────────────────────── v3.100.2+0
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed IterativeSolvers ───────────────── v0.9.4
#    Installed Libiconv_jll ───────────────────── v1.18.0+0
#    Installed URIs ───────────────────────────── v1.5.1
#    Installed StructArrays ───────────────────── v0.6.18
#    Installed HostCPUFeatures ────────────────── v0.1.17
#    Installed LaTeXStrings ───────────────────── v1.4.0
#    Installed CubicSplines ───────────────────── v0.2.1
#    Installed Glib_jll ───────────────────────── v2.82.4+0
#    Installed libvorbis_jll ──────────────────── v1.3.7+2
#    Installed ErrorfreeArithmetic ────────────── v0.5.2
#    Installed libsixel_jll ───────────────────── v1.10.5+0
#    Installed Libglvnd_jll ───────────────────── v1.7.0+0
#    Installed FilePathsBase ──────────────────── v0.9.22
#    Installed ForwardDiff ────────────────────── v0.10.38
#    Installed QuadGK ─────────────────────────── v2.11.1
#    Installed FillArrays ─────────────────────── v1.13.0
#    Installed JuliaNVTXCallbacks_jll ─────────── v0.2.1+0
#    Installed MPItrampoline_jll ──────────────── v5.5.1+2
#    Installed AxisAlgorithms ─────────────────── v1.1.0
#    Installed DelaunayTriangulation ──────────── v1.6.4
#    Installed Requires ───────────────────────── v1.3.0
#    Installed ImageAxes ──────────────────────── v0.6.12
#    Installed CRlibm ─────────────────────────── v1.0.1
#    Installed Xorg_libX11_jll ────────────────── v1.8.6+3
#    Installed Xorg_libXdmcp_jll ──────────────── v1.1.5+0
#    Installed Distributions ──────────────────── v0.25.117
#    Installed Observables ────────────────────── v0.5.5
#    Installed GeoInterface ───────────────────── v1.4.1
#    Installed CRlibm_jll ─────────────────────── v1.0.1+0
#    Installed ImageMorphology ────────────────── v0.4.5
#    Installed WoodburyMatrices ───────────────── v1.0.0
#    Installed StringManipulation ─────────────── v0.4.0
#    Installed SortingAlgorithms ──────────────── v1.2.1
#    Installed CUDA ───────────────────────────── v5.5.2
#    Installed libwebp_jll ────────────────────── v1.5.0+0
#    Installed DiskArrays ─────────────────────── v0.4.8
#    Installed Makie ──────────────────────────── v0.22.0
# Precompiling CUDA_Driver_jll...
#     940.2 ms  ✓ CUDA_Driver_jll
#   1 dependency successfully precompiled in 3 seconds. 28 already precompiled.
#     Updating `~/Work/git/drakkar2025-demo-oceananigans/Project.toml`
#   [0376089a] ~ ClimaOcean v0.3.3 `https://github.com/CliMA/ClimaOcean.jl.git#main` ⇒ v0.3.3
#   [5789e2e9] + FileIO v1.16.6
#   [ade2ca70] ~ Dates ⇒ v1.11.0
#     Updating `~/Work/git/drakkar2025-demo-oceananigans/Manifest.toml`
#  [0376089a] ~ ClimaOcean v0.3.3 `https://github.com/CliMA/ClimaOcean.jl.git#main` ⇒ v0.3.3
#   [35d6a980] ↑ ColorSchemes v3.27.1 ⇒ v3.28.0
#   [927a84f5] ↑ DelaunayTriangulation v1.6.3 ⇒ v1.6.4
#   [3c3547ce] ↑ DiskArrays v0.4.7 ⇒ v0.4.8
#   [31c24e10] ↑ Distributions v0.25.116 ⇒ v0.25.117
#   [68eda718] ↑ GeoFormatTypes v0.4.3 ⇒ v0.4.4
#   [cf35fbd7] ↑ GeoInterface v1.4.0 ⇒ v1.4.1
#   [63c18a36] ↑ KernelAbstractions v0.9.31 ⇒ v0.9.32
#   [10745b16] ↑ Statistics v1.10.0 ⇒ v1.11.1
#   [0dad84c5] ↑ ArgTools v1.1.1 ⇒ v1.1.2
#   [56f22d72] ~ Artifacts ⇒ v1.11.0
#   [2a0f44e3] ~ Base64 ⇒ v1.11.0
#   [8bf52ea8] ~ CRC32c ⇒ v1.11.0
#   [ade2ca70] ~ Dates ⇒ v1.11.0
#   [8ba89e20] ~ Distributed ⇒ v1.11.0
#   [7b1f6079] ~ FileWatching ⇒ v1.11.0
#   [9fa8497b] ~ Future ⇒ v1.11.0
#   [b77e0a4c] ~ InteractiveUtils ⇒ v1.11.0
#   [4af54fe1] ~ LazyArtifacts ⇒ v1.11.0
#   [76f85450] ~ LibGit2 ⇒ v1.11.0
#   [8f399da3] ~ Libdl ⇒ v1.11.0
#   [37e2e46d] ~ LinearAlgebra ⇒ v1.11.0
#   [56ddb016] ~ Logging ⇒ v1.11.0
#   [d6f4376e] ~ Markdown ⇒ v1.11.0
#   [a63ad114] ~ Mmap ⇒ v1.11.0
#   [44cfe95a] ↑ Pkg v1.10.0 ⇒ v1.11.0
#   [de0858da] ~ Printf ⇒ v1.11.0
#   [3fa0cd96] ~ REPL ⇒ v1.11.0
#   [9a3f8284] ~ Random ⇒ v1.11.0
#   [9e88b42a] ~ Serialization ⇒ v1.11.0
#   [1a1011a3] ~ SharedArrays ⇒ v1.11.0
#   [6462fe0b] ~ Sockets ⇒ v1.11.0
#   [2f01184e] ↑ SparseArrays v1.10.0 ⇒ v1.11.0
#   [f489334b] + StyledStrings v1.11.0
#   [8dfed614] ~ Test ⇒ v1.11.0
#   [cf7118a7] ~ UUIDs ⇒ v1.11.0
#   [4ec0a83e] ~ Unicode ⇒ v1.11.0
#   [deac9b47] ↑ LibCURL_jll v8.4.0+0 ⇒ v8.6.0+0
#   [e37daf67] ↑ LibGit2_jll v1.6.4+0 ⇒ v1.7.2+0
#   [c8ffd9c3] ↑ MbedTLS_jll v2.28.2+1 ⇒ v2.28.6+0
#   [14a3606d] ↑ MozillaCACerts_jll v2023.1.10 ⇒ v2023.12.12
#   [4536629a] ↑ OpenBLAS_jll v0.3.23+4 ⇒ v0.3.27+1
#   [bea87d4a] ↑ SuiteSparse_jll v7.2.1+1 ⇒ v7.7.0+0
#   [8e850ede] ↑ nghttp2_jll v1.52.0+1 ⇒ v1.59.0+0
# Precompiling project...
#    1004.9 ms  ✓ RangeArrays
#    1218.0 ms  ✓ LLVMLoopInfo
#    1823.3 ms  ✓ AbstractFFTs
#    2040.7 ms  ✓ LaTeXStrings
#    2511.5 ms  ✓ ErrorfreeArithmetic
#    2820.6 ms  ✓ IndirectArrays
#    3176.5 ms  ✓ PolygonOps
#    3592.2 ms  ✓ ExprTools
#    3951.8 ms  ✓ Glob
#    3568.7 ms  ✓ IteratorInterfaceExtensions
#    3520.3 ms  ✓ TensorCore
#    3745.5 ms  ✓ StatsAPI
#    4963.4 ms  ✓ UnsafeAtomics
#    3648.6 ms  ✓ GeoFormatTypes
#    3744.3 ms  ✓ Contour
#    3759.3 ms  ✓ CEnum
#    3908.4 ms  ✓ TriplotBase
#    4403.7 ms  ✓ OffsetArrays
#    3386.9 ms  ✓ UnPack
#    4487.4 ms  ✓ Format
#    4109.1 ms  ✓ InverseFunctions
#    4320.3 ms  ✓ FillArrays
#    4412.8 ms  ✓ SeawaterPolynomials
#    4480.9 ms  ✓ Statistics
#    4305.7 ms  ✓ CommonSolve
#    4119.4 ms  ✓ IterTools
#    4826.5 ms  ✓ RandomNumbers
#    4666.1 ms  ✓ Grisu
#    3995.1 ms  ✓ ManualMemory
#    4598.8 ms  ✓ OrderedCollections
#    6813.7 ms  ✓ MacroTools
#    4638.1 ms  ✓ Observables
#    4758.8 ms  ✓ Requires
#    4804.2 ms  ✓ DataValueInterfaces
#    4584.7 ms  ✓ EnumX
#    3488.5 ms  ✓ RealDot
#    3629.0 ms  ✓ StableRNGs
#    4121.8 ms  ✓ Reexport
#    3847.2 ms  ✓ SIMDTypes
#    4730.4 ms  ✓ InlineStrings
#    4672.1 ms  ✓ AbstractTrees
#    4995.9 ms  ✓ IrrationalConstants
#    4771.6 ms  ✓ IntervalSets
#    4921.5 ms  ✓ URIs
#    4766.3 ms  ✓ RoundingEmulator
#    4582.1 ms  ✓ SimpleBufferStream
#    4597.0 ms  ✓ CompositionsBase
#    4694.1 ms  ✓ Extents
#    3995.4 ms  ✓ PtrArrays
#    4180.4 ms  ✓ TranscodingStreams
#    5668.1 ms  ✓ CUDA_Runtime_Discovery
#    4631.5 ms  ✓ NaNMath
#    4864.3 ms  ✓ LazyModules
#    6149.0 ms  ✓ AdaptivePredicates
#    5076.7 ms  ✓ SetRounding
#    5145.4 ms  ✓ InvertedIndices
#    5260.8 ms  ✓ LRUCache
#    5511.4 ms  ✓ Inflate
#    4447.6 ms  ✓ IfElse
#    4511.6 ms  ✓ ConstructionBase
#    4278.0 ms  ✓ CommonWorldInvalidations
#    4287.0 ms  ✓ DataAPI
#    4794.6 ms  ✓ BitFlags
#    5493.0 ms  ✓ Crayons
#    4842.6 ms  ✓ StaticArraysCore
#    4854.3 ms  ✓ MappedArrays
#    5701.8 ms  ✓ ConcurrentUtilities
#    5407.7 ms  ✓ IOCapture
#    5481.2 ms  ✓ Suppressor
#    6508.9 ms  ✓ ProgressMeter
#    6658.2 ms  ✓ PDMats
#    5873.5 ms  ✓ WoodburyMatrices
#    5977.2 ms  ✓ IncompleteLU
#    6490.4 ms  ✓ CFTime
#    7521.5 ms  ✓ SentinelArrays
#    5925.1 ms  ✓ Scratch
#    5933.5 ms  ✓ LoggingExtras
#    5323.3 ms  ✓ CpuId
#    5049.6 ms  ✓ Compat
#    5460.2 ms  ✓ DocStringExtensions
#    5400.1 ms  ✓ MPIPreferences
#    4649.4 ms  ✓ CubicSplines
#    4872.6 ms  ✓ ExceptionUnwrapping
#    5976.9 ms  ✓ UnicodeFun
#    4806.6 ms  ✓ BFloat16s
#    4713.5 ms  ✓ OpenSSL_jll
#    4810.9 ms  ✓ CUDA_Driver_jll
#    4758.5 ms  ✓ Graphite2_jll
#    4765.6 ms  ✓ Libmount_jll
#    4451.9 ms  ✓ LLVMOpenMP_jll
#    4197.3 ms  ✓ Bzip2_jll
#    4819.8 ms  ✓ Lz4_jll
#    5190.5 ms  ✓ libaec_jll
#    4956.2 ms  ✓ NVTX_jll
#    5317.5 ms  ✓ Rmath_jll
#    5431.2 ms  ✓ Xorg_libXau_jll
#    5718.7 ms  ✓ libpng_jll
#    5654.3 ms  ✓ libfdk_aac_jll
#    5729.2 ms  ✓ Hwloc_jll
#    5551.2 ms  ✓ Imath_jll
#    5422.6 ms  ✓ demumble_jll
#    5574.8 ms  ✓ Giflib_jll
#    5332.1 ms  ✓ LAME_jll
#    5271.2 ms  ✓ LERC_jll
#    5092.9 ms  ✓ EarCut_jll
#    5141.0 ms  ✓ CRlibm_jll
#    5216.5 ms  ✓ JpegTurbo_jll
#    5197.4 ms  ✓ XZ_jll
#    5059.6 ms  ✓ Ogg_jll
#    5151.0 ms  ✓ oneTBB_jll
#    5086.4 ms  ✓ Xorg_libXdmcp_jll
#    5352.7 ms  ✓ x265_jll
#    5636.9 ms  ✓ x264_jll
#    6439.4 ms  ✓ libaom_jll
#    6598.6 ms  ✓ Zstd_jll
#    6955.5 ms  ✓ Expat_jll
#    7377.6 ms  ✓ LZO_jll
#   35136.9 ms  ✓ Unitful
#    7453.8 ms  ✓ Opus_jll
#    7508.0 ms  ✓ JuliaNVTXCallbacks_jll
#    7187.8 ms  ✓ MicrosoftMPI_jll
#    6794.1 ms  ✓ Xorg_xtrans_jll
#    5995.4 ms  ✓ Libiconv_jll
#    5653.3 ms  ✓ Libffi_jll
#    5200.5 ms  ✓ Libgpg_error_jll
#    4728.7 ms  ✓ isoband_jll
#    4691.1 ms  ✓ FFTW_jll
#    5023.8 ms  ✓ OpenSpecFun_jll
#    4800.8 ms  ✓ Xorg_libpthread_stubs_jll
#    4784.5 ms  ✓ FriBidi_jll
#    4879.3 ms  ✓ Libuuid_jll
#    6851.5 ms  ✓ RecipesBase
#    7911.9 ms  ✓ StringManipulation
#    7338.0 ms  ✓ PkgVersion
#    7454.9 ms  ✓ IntelOpenMP_jll
#    7966.5 ms  ✓ LLVMExtra_jll
#   10358.7 ms  ✓ FastRounding
#   11066.9 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    8821.5 ms  ✓ TableTraits
#    8396.5 ms  ✓ Atomix
#    8914.3 ms  ✓ StackViews
#    8360.1 ms  ✓ PaddedViews
#   17109.5 ms  ✓ SIMD
#   14538.4 ms  ✓ TimerOutputs
#    5799.5 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    9313.2 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    9191.1 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    4218.8 ms  ✓ Showoff
#    6911.0 ms  ✓ Statistics → SparseArraysExt
#    9154.7 ms  ✓ SignedDistanceFields
#    6695.6 ms  ✓ FillArrays → FillArraysStatisticsExt
#   10210.9 ms  ✓ FixedPointNumbers
#    7692.9 ms  ✓ ThreadingUtilities
#   10176.7 ms  ✓ Distances
#    3570.6 ms  ✓ Ratios
#    4173.0 ms  ✓ Adapt
#   11346.4 ms  ✓ Random123
#    7215.2 ms  ✓ CommonSubexpressions
#    6835.8 ms  ✓ SimpleTraits
#    8360.3 ms  ✓ TaylorSeries
#    8150.7 ms  ✓ Quaternions
#    8675.8 ms  ✓ InlineStrings → ParsersExt
#    8945.8 ms  ✓ IntervalSets → IntervalSetsRandomExt
#    8346.6 ms  ✓ IntervalSets → IntervalSetsStatisticsExt
#    8603.7 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    9009.9 ms  ✓ AliasTables
#    9492.2 ms  ✓ CodecZlib
#   13606.9 ms  ✓ FileIO
#    9845.0 ms  ✓ LRUCache → SerializationExt
#    8105.6 ms  ✓ DiskArrays
#    9073.2 ms  ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#    8398.1 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    7105.2 ms  ✓ Missings
#    8768.9 ms  ✓ PooledArrays
#    8493.0 ms  ✓ DiffResults
#   14175.2 ms  ✓ Static
#   14469.4 ms  ✓ GeoInterface
#   10302.9 ms  ✓ Literate
#    9181.8 ms  ✓ FillArrays → FillArraysPDMatsExt
#    9817.6 ms  ✓ AxisAlgorithms
#    9200.2 ms  ✓ RelocatableFolders
#    9760.5 ms  ✓ Compat → CompatLinearAlgebraExt
#   15742.9 ms  ✓ StaticArrays
#    9798.4 ms  ✓ MPItrampoline_jll
#    5367.8 ms  ✓ OpenMPI_jll
#   13575.0 ms  ✓ LogExpFunctions
#    9832.1 ms  ✓ CUDA_Runtime_jll
#   12639.2 ms  ✓ Pixman_jll
#   13422.3 ms  ✓ FreeType2_jll
#   13159.8 ms  ✓ Rmath
#   13783.6 ms  ✓ MPICH_jll
#   12549.7 ms  ✓ OpenEXR_jll
#   13108.6 ms  ✓ CRlibm
#   22415.5 ms  ✓ OpenSSL
#   13034.4 ms  ✓ libvorbis_jll
#    8815.2 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#    7532.1 ms  ✓ Unitful → InverseFunctionsUnitfulExt
#   23835.7 ms  ✓ libsixel_jll
#   20168.5 ms  ✓ Blosc_jll
#   18901.8 ms  ✓ libzip_jll
#   12040.6 ms  ✓ Libgcrypt_jll
#   11793.6 ms  ✓ Isoband
#    7901.6 ms  ✓ IntervalSets → IntervalSetsRecipesBaseExt
#   14869.3 ms  ✓ XML2_jll
#    9390.9 ms  ✓ IterativeSolvers
#    5417.6 ms  ✓ MKL_jll
#   24120.5 ms  ✓ Libtiff_jll
#    4431.5 ms  ✓ ArrayInterface
#    8341.1 ms  ✓ Distances → DistancesSparseArraysExt
#    9650.7 ms  ✓ ColorTypes
#    8510.5 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    5549.5 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    8244.9 ms  ✓ GPUArraysCore
#   17240.8 ms  ✓ Tables
#   16835.1 ms  ✓ MosaicViews
#    8642.2 ms  ✓ CubedSphere
#   20508.5 ms  ✓ LLVM
#    9862.8 ms  ✓ BitTwiddlingConvenienceFunctions
#   23753.8 ms  ✓ Automa
#    6779.7 ms  ✓ FilePathsBase
#    7367.0 ms  ✓ ChainRulesCore
#   11183.2 ms  ✓ DataStructures
#   11662.7 ms  ✓ CPUSummary
#   18692.5 ms  ✓ AxisArrays
#   17792.2 ms  ✓ Accessors
#    9122.6 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    8590.0 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    6791.2 ms  ✓ Adapt → AdaptStaticArraysExt
#    5684.9 ms  ✓ TaylorSeries → TaylorSeriesSAExt
#    8145.8 ms  ✓ Rotations
#    8876.8 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    9992.1 ms  ✓ FreeType
#   19384.1 ms  ✓ SpecialFunctions
#   26774.2 ms  ✓ Fontconfig_jll
#   18471.9 ms  ✓ Gettext_jll
#   31662.4 ms  ✓ HDF5_jll
#   29403.9 ms  ✓ IntervalArithmetic
#   55677.0 ms  ✓ JLD2
#   39114.4 ms  ✓ GeometryBasics
#   16869.8 ms  ✓ XSLT_jll
#    5311.5 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    6720.2 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   11186.1 ms  ✓ StaticArrayInterface
#   40030.3 ms  ✓ MPI
#    6612.6 ms  ✓ ColorTypes → StyledStringsExt
#    9042.7 ms  ✓ QOI
#    8307.3 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#   13595.4 ms  ✓ ColorVectorSpace
#    9258.4 ms  ✓ StructArrays
#   10969.9 ms  ✓ Colors
#    5893.3 ms  ✓ UnsafeAtomics → UnsafeAtomicsLLVM
#   14169.8 ms  ✓ LLVM → BFloat16sExt
#    7300.0 ms  ✓ GPUArrays
#    9863.9 ms  ✓ HostCPUFeatures
#   10384.8 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#    8414.0 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#    6155.5 ms  ✓ FilePaths
#   35381.7 ms  ✓ FFTW
#    5408.4 ms  ✓ Distances → DistancesChainRulesCoreExt
#    6173.7 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    9793.4 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    6118.0 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    6077.1 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    8259.3 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   66289.2 ms  ✓ HTTP
#    7869.2 ms  ✓ SortingAlgorithms
#    8532.5 ms  ✓ QuadGK
#    9623.2 ms  ✓ CommonDataModel
#    6754.6 ms  ✓ Accessors → LinearAlgebraExt
#    4050.3 ms  ✓ Accessors → IntervalSetsExt
#    5213.8 ms  ✓ Accessors → TestExt
#    4396.6 ms  ✓ Accessors → UnitfulExt
#   10077.3 ms  ✓ PolyesterWeave
#    4714.5 ms  ✓ Accessors → StaticArraysExt
#    4524.8 ms  ✓ DiffRules
#    9612.6 ms  ✓ Rotations → RotationsRecipesBaseExt
#   10894.7 ms  ✓ HypergeometricFunctions
#   14235.0 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   54518.6 ms  ✓ PrettyTables
#    8814.2 ms  ✓ TaylorSeries → TaylorSeriesIAExt
#   21309.5 ms  ✓ KernelAbstractions
#   58800.1 ms  ✓ GPUCompiler
#   16131.5 ms  ✓ ExactPredicates
#   12568.3 ms  ✓ TaylorSeries → TaylorSeriesJLD2Ext
#   24813.4 ms  ✓ Glib_jll
#    8056.3 ms  ✓ Packing
#    4677.2 ms  ✓ Xorg_libxcb_jll
#   12135.6 ms  ✓ ShaderAbstractions
#    6006.3 ms  ✓ CloseOpenIntervals
#    7096.6 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    8697.0 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   18826.4 ms  ✓ GridLayoutBase
#    7374.2 ms  ✓ LayoutPointers
#   15495.5 ms  ✓ MakieCore
#    8150.9 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    7576.6 ms  ✓ StructArrays → StructArraysAdaptExt
#    4600.8 ms  ✓ Accessors → StructArraysExt
#    5747.3 ms  ✓ StructArrays → StructArraysGPUArraysCoreExt
#    7872.0 ms  ✓ StructArrays → StructArraysSparseArraysExt
#    7453.4 ms  ✓ StructArrays → StructArraysStaticArraysExt
#   37100.4 ms  ✓ NetCDF_jll
#    6560.3 ms  ✓ Animations
#    5817.6 ms  ✓ ColorBrewer
#    8939.2 ms  ✓ Graphics
#    7927.4 ms  ✓ FreeTypeAbstraction
#    8900.7 ms  ✓ ColorSchemes
#   12722.6 ms  ✓ NVTX
#    7917.5 ms  ✓ FileIO → HTTPExt
#   11269.3 ms  ✓ DataDeps
#   14216.8 ms  ✓ Roots
#   26233.3 ms  ✓ OpenEXR
#   20837.6 ms  ✓ Interpolations
#   12664.3 ms  ✓ StatsFuns
#   20721.3 ms  ✓ StatsBase
#    6782.3 ms  ✓ Xorg_libX11_jll
#    8485.4 ms  ✓ KernelAbstractions → LinearAlgebraExt
#   34547.1 ms  ✓ ImageCore
#   11361.6 ms  ✓ KernelAbstractions → SparseArraysExt
#   23646.1 ms  ✓ ForwardDiff
#   11004.9 ms  ✓ TiledIteration
#   12447.9 ms  ✓ Roots → RootsChainRulesCoreExt
#  102528.5 ms  ✓ TiffImages
#   13535.7 ms  ✓ Interpolations → InterpolationsUnitfulExt
#   28540.4 ms  ✓ DelaunayTriangulation
#    9092.8 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    4068.1 ms  ✓ Xorg_libXrender_jll
#    8944.0 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   28104.8 ms  ✓ VectorizationBase
#    4806.0 ms  ✓ Xorg_libXext_jll
#   29256.1 ms  ✓ NCDatasets
#   32513.2 ms  ✓ PlotUtils
#   11454.7 ms  ✓ ImageBase
#    5358.8 ms  ✓ RootSolvers
#   10856.4 ms  ✓ JpegTurbo
#    9855.1 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   14584.0 ms  ✓ PNGFiles
#    4520.9 ms  ✓ Roots → RootsForwardDiffExt
#   41884.3 ms  ✓ MathTeXEngine
#   15312.8 ms  ✓ Sixel
#    4386.8 ms  ✓ Libglvnd_jll
#    7091.9 ms  ✓ SLEEFPirates
#   27538.1 ms  ✓ Distributions
#   14400.8 ms  ✓ ImageAxes
#    7189.9 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    7335.7 ms  ✓ Distributions → DistributionsTestExt
#   14992.5 ms  ✓ Thermodynamics
#   15892.1 ms  ✓ libwebp_jll
#    8029.6 ms  ✓ ImageMetadata
#   11016.2 ms  ✓ SurfaceFluxes
#   87337.3 ms  ✓ DataFrames
#   10021.5 ms  ✓ Netpbm
#   35688.0 ms  ✓ Cairo_jll
#   22554.4 ms  ✓ KernelDensity
#   19529.1 ms  ✓ WebP
#    3773.9 ms  ✓ ImageIO
#    9678.9 ms  ✓ HarfBuzz_jll
#    7366.3 ms  ✓ libass_jll
#    7433.8 ms  ✓ Pango_jll
#   49050.7 ms  ✓ LoopVectorization
#    4620.7 ms  ✓ LoopVectorization → SpecialFunctionsExt
#    4794.8 ms  ✓ LoopVectorization → ForwardDiffExt
#   11308.6 ms  ✓ Cairo
#    8420.8 ms  ✓ ImageMorphology
#   18767.3 ms  ✓ FFMPEG_jll
#   66081.5 ms  ✓ CUDA
#    9354.2 ms  ✓ ArrayInterface → ArrayInterfaceCUDAExt
#    9407.1 ms  ✓ Atomix → AtomixCUDAExt
#    9412.5 ms  ✓ CUDA → ChainRulesCoreExt
#    9570.4 ms  ✓ CUDA → SpecialFunctionsExt
#   10417.3 ms  ✓ MPI → CUDAExt
#   33518.1 ms  ✓ Oceananigans
#    9872.2 ms  ✓ OrthogonalSphericalShellGrids
#   10641.4 ms  ✓ ClimaSeaIce
#   18013.7 ms  ✓ ClimaOcean
#  170631.1 ms  ✓ Makie
#   12648.5 ms  ✓ Oceananigans → OceananigansMakieExt
#   47646.9 ms  ✓ CairoMakie
#   377 dependencies successfully precompiled in 678 seconds. 54 already precompiled.

# %% [markdown]
# We run this example on a CPU.
# To run it on a GPU, replace `CPU()` with `GPU()` and crank up the resolution!

# %%
arch = CPU()
# Out:
# CPU()

# %% [markdown]
# We start with defining a 2D grid in the x-z plane with 512x256 grid points.
# This is not enough to resolve the Kolmogorov scale so we are in an LES regime

# %%
Nx, Ny = 256, 256
grid = RectilinearGrid(arch,
                       size = (Nx, Ny),
                       x = (0, 0.5),
                       z = (-0.5, 0.0),
                       topology = (Bounded, Flat, Bounded))
# Out:
# 256×1×256 RectilinearGrid{Float64, Bounded, Flat, Bounded} on CPU with 3×0×3 halo
# ├── Bounded  x ∈ [0.0, 0.5]  regularly spaced with Δx=0.00195312
# ├── Flat y
# └── Bounded  z ∈ [-0.5, 0.0] regularly spaced with Δz=0.00195312

# %% [markdown]
# We use the TEOS10 equation of state to compute the density of seawater.
# This is a nonlinear equation of state that depends on temperature, salinity and pressure.
# We set the salinity to zero and the gravitational acceleration to 9.81 m/s².

# %%
equation_of_state = TEOS10EquationOfState(reference_density=1000)
buoyancy = SeawaterBuoyancy(; equation_of_state,
                              constant_salinity=0,
                              gravitational_acceleration=9.81)
# Out:
# SeawaterBuoyancy{Float64}:
# ├── gravitational_acceleration: 9.81
# ├── constant_salinity: 0
# └── equation_of_state: BoussinesqEquationOfState{Float64}

# %% [markdown]
# Since we are in an LES regime we need a LES closure. In this case we use a high-order WENO
# scheme to provide us the implicit diffusion necessary to represent subgrid-scale diffusion in
# the model. Other options would include an explicit closure like
# the Smagorinsky model (`closure = AnisotropicMinimumDissipation()`).

# %%
model = NonhydrostaticModel(; grid,
                              buoyancy,
                              advection=WENO(order=7),
                              tracers=:T)
# Out:
# ┌ Warning: Inflating model grid halo size to (4, 0, 4) and recreating grid. Note that an ImmersedBoundaryGrid requires an extra halo point in all non-flat directions compared to a non-immersed boundary grid.
# └ @ Oceananigans.Models.NonhydrostaticModels ~/.julia/packages/Oceananigans/kGlF8/src/Models/NonhydrostaticModels/nonhydrostatic_model.jl:248
# NonhydrostaticModel{CPU, RectilinearGrid}(time = 0 seconds, iteration = 0)
# ├── grid: 256×1×256 RectilinearGrid{Float64, Bounded, Flat, Bounded} on CPU with 4×0×4 halo
# ├── timestepper: RungeKutta3TimeStepper
# ├── advection scheme: WENO(order=7)
# ├── tracers: T
# ├── closure: Nothing
# ├── buoyancy: SeawaterBuoyancy with g=9.81 and BoussinesqEquationOfState{Float64} with ĝ = NegativeZDirection()
# └── coriolis: Nothing

# %% [markdown]
# Setting the initial conditions to an unstable equilibrium with hot water above (and below) cold water.
# and some random perturbations in the velocity field to trigger the instability.
# To give it a nice spin, let's initialize the temperature field with the Drakkar Ocean logo.

# %%
T₁, T₂ = 1, 7.55 # ᵒC
Ξᵢ = (x, z) -> 1e-4 * randn()

using FileIO

download("https://drakkar2025.sciencesconf.org/data/header/DrakkarOcean_1.png", "logo-drakkar.png")

img   = FileIO.load("logo-drakkar.png")
alpha = getproperty.(img, :alpha) .|> Float64
alpha = reverse(alpha', dims=2)
alpha = alpha[1:2:end, 1:2:end]
borderx = zeros((256 - size(alpha, 1)) ÷ 2, size(alpha, 2))
alpha   = vcat(borderx, alpha, borderx)
bordery = zeros(size(alpha, 1), (256 - size(alpha, 2)) ÷ 2)
alpha   = hcat(bordery, alpha, bordery)

Tᵢ = [ifelse(alpha[i, j] == 0, T₁, T₂) for i in 1:Nx, j in 1:Ny]

set!(model, T=Tᵢ, u=Ξᵢ, v=Ξᵢ, w=Ξᵢ)
# Out:
# ┌ Warning: Reshaped 256×256 Matrix{Real} to set! its data to
# │ 256×1×256 Field{Center, Center, Center} on RectilinearGrid on CPU
# └ @ Oceananigans.Fields ~/.julia/packages/Oceananigans/kGlF8/src/Fields/set!.jl:112

# %% [markdown]
# We set the time step to 0.2 seconds and the stop time to 100 seconds.

# %%
simulation = Simulation(model; Δt = 0.1, stop_time=100)
# Out:
# Simulation of NonhydrostaticModel{CPU, RectilinearGrid}(time = 0 seconds, iteration = 0)
# ├── Next time step: 100 ms
# ├── Elapsed wall time: 0 seconds
# ├── Wall time per iteration: NaN days
# ├── Stop time: 1.667 minutes
# ├── Stop iteration: Inf
# ├── Wall time limit: Inf
# ├── Minimum relative step: 0.0
# ├── Callbacks: OrderedDict with 4 entries:
# │   ├── stop_time_exceeded => Callback of stop_time_exceeded on IterationInterval(1)
# │   ├── stop_iteration_exceeded => Callback of stop_iteration_exceeded on IterationInterval(1)
# │   ├── wall_time_limit_exceeded => Callback of wall_time_limit_exceeded on IterationInterval(1)
# │   └── nan_checker => Callback of NaNChecker for u on IterationInterval(100)
# ├── Output writers: OrderedDict with no entries
# └── Diagnostics: OrderedDict with no entries

# %% [markdown]
# We add a callback to print the progress of the simulation every 10 iterations.

# %%
function progress(sim)
    u, v, w = sim.model.velocities
    @info string("Iter: ", iteration(sim), ", time: ", prettytime(sim), ", max(w): ", maximum(abs, w))
end

add_callback!(simulation, progress, IterationInterval(10))

# %% [markdown]
# We use a variable time-stepping to make sure we don't overshoot the CFL condition.

# %%
conjure_time_step_wizard!(simulation, cfl=0.7)

# %% [markdown]
# Let's set an output writer to collect the density and temperature fields every second.

# %%
ρ = seawater_density(model)
T = model.tracers.T

output_writer = JLD2OutputWriter(model, (; ρ, T),
                                 filename = "cabbeling",
                                 schedule = TimeInterval(1),
                                 overwrite_existing = true)

simulation.output_writers[:jld2] = output_writer
# Out:
# JLD2OutputWriter scheduled on TimeInterval(1 second):
# ├── filepath: cabbeling.jld2
# ├── 2 outputs: (ρ, T)
# ├── array type: Array{Float64}
# ├── including: [:grid, :coriolis, :buoyancy, :closure]
# ├── file_splitting: NoFileSplitting
# └── file size: 3.2 MiB

# %% [markdown]
# Running the simulation!

# %%
run!(simulation)
# Out:
# [ Info: Initializing simulation...
# [ Info: Iter: 0, time: 0 seconds, max(w): 0.00037000359779137997
# [ Info:     ... simulation initialization complete (15.109 seconds)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (4.993 seconds).
# [ Info: Iter: 10, time: 1 second, max(w): 0.0003536769158886388
# [ Info: Iter: 20, time: 2.121 seconds, max(w): 0.00038838589555555933
# [ Info: Iter: 30, time: 3.399 seconds, max(w): 0.000691791700089361
# [ Info: Iter: 40, time: 4.586 seconds, max(w): 0.0010588967098071553
# [ Info: Iter: 50, time: 6 seconds, max(w): 0.001709777208281509
# [ Info: Iter: 60, time: 7.709 seconds, max(w): 0.0025961396338666696
# [ Info: Iter: 70, time: 9.390 seconds, max(w): 0.003430676502503361
# [ Info: Iter: 80, time: 11.429 seconds, max(w): 0.004063951079138737
# [ Info: Iter: 90, time: 13.472 seconds, max(w): 0.005129095130514524
# [ Info: Iter: 100, time: 15.472 seconds, max(w): 0.0057539340193409
# [ Info: Iter: 110, time: 17.416 seconds, max(w): 0.006332666758706888
# [ Info: Iter: 120, time: 19.000 seconds, max(w): 0.006434346263382057
# [ Info: Iter: 130, time: 20.479 seconds, max(w): 0.006658052861630281
# [ Info: Iter: 140, time: 21.918 seconds, max(w): 0.006877212924211906
# [ Info: Iter: 150, time: 23.309 seconds, max(w): 0.00751532148956588
# [ Info: Iter: 160, time: 24.767 seconds, max(w): 0.008297805883100985
# [ Info: Iter: 170, time: 26 seconds, max(w): 0.008116895763459767
# [ Info: Iter: 180, time: 27.258 seconds, max(w): 0.00823430433620827
# [ Info: Iter: 190, time: 28.526 seconds, max(w): 0.008337925177604143
# [ Info: Iter: 200, time: 29.772 seconds, max(w): 0.008457720078110718
# [ Info: Iter: 210, time: 31 seconds, max(w): 0.008543848402138308
# [ Info: Iter: 220, time: 32.264 seconds, max(w): 0.008080059931228062
# [ Info: Iter: 230, time: 33.533 seconds, max(w): 0.007415506264855132
# [ Info: Iter: 240, time: 34.777 seconds, max(w): 0.007123587371107188
# [ Info: Iter: 250, time: 36 seconds, max(w): 0.00727146764231534
# [ Info: Iter: 260, time: 37.258 seconds, max(w): 0.007871641553112749
# [ Info: Iter: 270, time: 38.366 seconds, max(w): 0.00840288080837668
# [ Info: Iter: 280, time: 39.469 seconds, max(w): 0.008832800770558723
# [ Info: Iter: 290, time: 40.594 seconds, max(w): 0.00899294320070197
# [ Info: Iter: 300, time: 41.682 seconds, max(w): 0.009051241177293366
# [ Info: Iter: 310, time: 42.788 seconds, max(w): 0.009030849830906322
# [ Info: Iter: 320, time: 43.849 seconds, max(w): 0.009662169515394921
# [ Info: Iter: 330, time: 44.784 seconds, max(w): 0.00990919832184755
# [ Info: Iter: 340, time: 45.648 seconds, max(w): 0.009898808753094495
# [ Info: Iter: 350, time: 46.438 seconds, max(w): 0.00992053748462919
# [ Info: Iter: 360, time: 47.256 seconds, max(w): 0.009988631548500302
# [ Info: Iter: 370, time: 48.086 seconds, max(w): 0.009941656222163713
# [ Info: Iter: 380, time: 48.947 seconds, max(w): 0.009917773477580738
# [ Info: Iter: 390, time: 49.774 seconds, max(w): 0.009890672325638583
# [ Info: Iter: 400, time: 50.599 seconds, max(w): 0.010169213829900733
# [ Info: Iter: 410, time: 51.439 seconds, max(w): 0.010595344588815237
# [ Info: Iter: 420, time: 52.275 seconds, max(w): 0.011029015688210792
# [ Info: Iter: 430, time: 53.191 seconds, max(w): 0.011338176161504213
# [ Info: Iter: 440, time: 54.095 seconds, max(w): 0.011624773888977674
# [ Info: Iter: 450, time: 55.000 seconds, max(w): 0.011695048618792607
# [ Info: Iter: 460, time: 55.913 seconds, max(w): 0.011777327584748087
# [ Info: Iter: 470, time: 56.825 seconds, max(w): 0.011972671486174416
# [ Info: Iter: 480, time: 57.756 seconds, max(w): 0.012006357004853179
# [ Info: Iter: 490, time: 58.680 seconds, max(w): 0.011698873873775979
# [ Info: Iter: 500, time: 59.596 seconds, max(w): 0.011595749087803668
# [ Info: Iter: 510, time: 1.008 minutes, max(w): 0.011533898699912566
# [ Info: Iter: 520, time: 1.023 minutes, max(w): 0.011691632902789515
# [ Info: Iter: 530, time: 1.038 minutes, max(w): 0.011821480124450343
# [ Info: Iter: 540, time: 1.053 minutes, max(w): 0.01189995871338822
# [ Info: Iter: 550, time: 1.067 minutes, max(w): 0.011918739164991476
# [ Info: Iter: 560, time: 1.082 minutes, max(w): 0.012004943505581291
# [ Info: Iter: 570, time: 1.095 minutes, max(w): 0.012238973364082532
# [ Info: Iter: 580, time: 1.109 minutes, max(w): 0.01256155574761234
# [ Info: Iter: 590, time: 1.123 minutes, max(w): 0.012847017715892046
# [ Info: Iter: 600, time: 1.136 minutes, max(w): 0.013288725083556668
# [ Info: Iter: 610, time: 1.150 minutes, max(w): 0.013769789253472196
# [ Info: Iter: 620, time: 1.165 minutes, max(w): 0.014147970067184197
# [ Info: Iter: 630, time: 1.178 minutes, max(w): 0.01487403356084189
# [ Info: Iter: 640, time: 1.192 minutes, max(w): 0.015696340974432996
# [ Info: Iter: 650, time: 1.205 minutes, max(w): 0.016497059744972998
# [ Info: Iter: 660, time: 1.218 minutes, max(w): 0.017183334471819307
# [ Info: Iter: 670, time: 1.231 minutes, max(w): 0.017991202560307472
# [ Info: Iter: 680, time: 1.243 minutes, max(w): 0.01885875931248615
# [ Info: Iter: 690, time: 1.255 minutes, max(w): 0.019510093105410763
# [ Info: Iter: 700, time: 1.266 minutes, max(w): 0.019994034366162955
# [ Info: Iter: 710, time: 1.277 minutes, max(w): 0.02023445909857226
# [ Info: Iter: 720, time: 1.288 minutes, max(w): 0.020192777690261954
# [ Info: Iter: 730, time: 1.299 minutes, max(w): 0.019826742895795984
# [ Info: Iter: 740, time: 1.310 minutes, max(w): 0.019171511998749283
# [ Info: Iter: 750, time: 1.321 minutes, max(w): 0.018387963083780136
# [ Info: Iter: 760, time: 1.333 minutes, max(w): 0.01762407811333283
# [ Info: Iter: 770, time: 1.346 minutes, max(w): 0.017101670862729082
# [ Info: Iter: 780, time: 1.359 minutes, max(w): 0.01679333984818905
# [ Info: Iter: 790, time: 1.372 minutes, max(w): 0.01657476731982241
# [ Info: Iter: 800, time: 1.383 minutes, max(w): 0.016370964985472723
# [ Info: Iter: 810, time: 1.395 minutes, max(w): 0.016092886685941023
# [ Info: Iter: 820, time: 1.407 minutes, max(w): 0.015746013068720272
# [ Info: Iter: 830, time: 1.418 minutes, max(w): 0.01531280878677698
# [ Info: Iter: 840, time: 1.429 minutes, max(w): 0.014956468543406978
# [ Info: Iter: 850, time: 1.440 minutes, max(w): 0.014920112335459736
# [ Info: Iter: 860, time: 1.451 minutes, max(w): 0.014978161815284188
# [ Info: Iter: 870, time: 1.463 minutes, max(w): 0.015468979159484928
# [ Info: Iter: 880, time: 1.475 minutes, max(w): 0.01596081975801995
# [ Info: Iter: 890, time: 1.487 minutes, max(w): 0.016365970965279933
# [ Info: Iter: 900, time: 1.499 minutes, max(w): 0.016442856749623914
# [ Info: Iter: 910, time: 1.511 minutes, max(w): 0.015846304801856753
# [ Info: Iter: 920, time: 1.523 minutes, max(w): 0.015008415496945501
# [ Info: Iter: 930, time: 1.535 minutes, max(w): 0.014358029566162816
# [ Info: Iter: 940, time: 1.546 minutes, max(w): 0.014999451077424295
# [ Info: Iter: 950, time: 1.557 minutes, max(w): 0.01568876326743543
# [ Info: Iter: 960, time: 1.569 minutes, max(w): 0.016467959596468462
# [ Info: Iter: 970, time: 1.582 minutes, max(w): 0.01705099602829004
# [ Info: Iter: 980, time: 1.593 minutes, max(w): 0.01716037501266227
# [ Info: Iter: 990, time: 1.605 minutes, max(w): 0.016642396456781002
# [ Info: Iter: 1000, time: 1.616 minutes, max(w): 0.01561140338985201
# [ Info: Iter: 1010, time: 1.626 minutes, max(w): 0.014320533938999245
# [ Info: Iter: 1020, time: 1.636 minutes, max(w): 0.0135982293437167
# [ Info: Iter: 1030, time: 1.647 minutes, max(w): 0.013774250089540852
# [ Info: Iter: 1040, time: 1.656 minutes, max(w): 0.01387808916630437
# [ Info: Simulation is stopping after running for 6.652 minutes.
# [ Info: Simulation time 1.667 minutes equals or exceeds stop time 1.667 minutes.
# [ Info: Iter: 1050, time: 1.667 minutes, max(w): 0.01392352880586736

# %% [markdown]
# ## Visualizing the simulation
#
# Let's use Makie to visualize the density and temperature fields in the x-z plane.

# %%
using CairoMakie

ρt = FieldTimeSeries("cabbeling.jld2", "ρ")
Tt = FieldTimeSeries("cabbeling.jld2", "T")

Nt = length(ρt)
Nx = size(ρt, 1)

i = Int(Nx / 2)
n = Observable(length(ρt.times))
ρ = @lift interior(ρt[$n], :, 1, :)
T = @lift interior(Tt[$n], :, 1, :)
x, y, z = nodes(ρt)

set_theme!(Theme(fontsize=12))
fig = Figure(size=(1000, 500))

ρrange = (minimum(ρt[1]), maximum(ρt))

axT = Axis(fig[1, 2], xlabel="x (m)", ylabel="z (m)")
xlims!(axT,  0, 0.5)
ylims!(axT, -0.5, 0)

axρ = Axis(fig[1, 3], xlabel="x (m)", ylabel="z (m)")
xlims!(axρ,  0, 0.5)
ylims!(axρ, -0.5, 0)

hm = heatmap!(axT, x, z, T, colormap=:magma, colorrange=(1.55, 7))
Colorbar(fig[1, 1], hm, label="Temperature (ᵒC)", flipaxis=false)

hm = heatmap!(axρ, x, z, ρ, colormap=Makie.Reverse(:grays), colorrange=ρrange)
Colorbar(fig[1, 4], hm, label="Density (kg m⁻³)")

record(fig, "cabbeling_2d.mp4", 1:Nt, framerate=5) do nn
    @info "Drawing frame $nn of $Nt..."
    n[] = nn
end
# Out:
# [ Info: Drawing frame 1 of 101...
# [ Info: Drawing frame 2 of 101...
# [ Info: Drawing frame 3 of 101...
# [ Info: Drawing frame 4 of 101...
# [ Info: Drawing frame 5 of 101...
# [ Info: Drawing frame 6 of 101...
# [ Info: Drawing frame 7 of 101...
# [ Info: Drawing frame 8 of 101...
# [ Info: Drawing frame 9 of 101...
# [ Info: Drawing frame 10 of 101...
# [ Info: Drawing frame 11 of 101...
# [ Info: Drawing frame 12 of 101...
# [ Info: Drawing frame 13 of 101...
# [ Info: Drawing frame 14 of 101...
# [ Info: Drawing frame 15 of 101...
# [ Info: Drawing frame 16 of 101...
# [ Info: Drawing frame 17 of 101...
# [ Info: Drawing frame 18 of 101...
# [ Info: Drawing frame 19 of 101...
# [ Info: Drawing frame 20 of 101...
# [ Info: Drawing frame 21 of 101...
# [ Info: Drawing frame 22 of 101...
# [ Info: Drawing frame 23 of 101...
# [ Info: Drawing frame 24 of 101...
# [ Info: Drawing frame 25 of 101...
# [ Info: Drawing frame 26 of 101...
# [ Info: Drawing frame 27 of 101...
# [ Info: Drawing frame 28 of 101...
# [ Info: Drawing frame 29 of 101...
# [ Info: Drawing frame 30 of 101...
# [ Info: Drawing frame 31 of 101...
# [ Info: Drawing frame 32 of 101...
# [ Info: Drawing frame 33 of 101...
# [ Info: Drawing frame 34 of 101...
# [ Info: Drawing frame 35 of 101...
# [ Info: Drawing frame 36 of 101...
# [ Info: Drawing frame 37 of 101...
# [ Info: Drawing frame 38 of 101...
# [ Info: Drawing frame 39 of 101...
# [ Info: Drawing frame 40 of 101...
# [ Info: Drawing frame 41 of 101...
# [ Info: Drawing frame 42 of 101...
# [ Info: Drawing frame 43 of 101...
# [ Info: Drawing frame 44 of 101...
# [ Info: Drawing frame 45 of 101...
# [ Info: Drawing frame 46 of 101...
# [ Info: Drawing frame 47 of 101...
# [ Info: Drawing frame 48 of 101...
# [ Info: Drawing frame 49 of 101...
# [ Info: Drawing frame 50 of 101...
# [ Info: Drawing frame 51 of 101...
# [ Info: Drawing frame 52 of 101...
# [ Info: Drawing frame 53 of 101...
# [ Info: Drawing frame 54 of 101...
# [ Info: Drawing frame 55 of 101...
# [ Info: Drawing frame 56 of 101...
# [ Info: Drawing frame 57 of 101...
# [ Info: Drawing frame 58 of 101...
# [ Info: Drawing frame 59 of 101...
# [ Info: Drawing frame 60 of 101...
# [ Info: Drawing frame 61 of 101...
# [ Info: Drawing frame 62 of 101...
# [ Info: Drawing frame 63 of 101...
# [ Info: Drawing frame 64 of 101...
# [ Info: Drawing frame 65 of 101...
# [ Info: Drawing frame 66 of 101...
# [ Info: Drawing frame 67 of 101...
# [ Info: Drawing frame 68 of 101...
# [ Info: Drawing frame 69 of 101...
# [ Info: Drawing frame 70 of 101...
# [ Info: Drawing frame 71 of 101...
# [ Info: Drawing frame 72 of 101...
# [ Info: Drawing frame 73 of 101...
# [ Info: Drawing frame 74 of 101...
# [ Info: Drawing frame 75 of 101...
# [ Info: Drawing frame 76 of 101...
# [ Info: Drawing frame 77 of 101...
# [ Info: Drawing frame 78 of 101...
# [ Info: Drawing frame 79 of 101...
# [ Info: Drawing frame 80 of 101...
# [ Info: Drawing frame 81 of 101...
# [ Info: Drawing frame 82 of 101...
# [ Info: Drawing frame 83 of 101...
# [ Info: Drawing frame 84 of 101...
# [ Info: Drawing frame 85 of 101...
# [ Info: Drawing frame 86 of 101...
# [ Info: Drawing frame 87 of 101...
# [ Info: Drawing frame 88 of 101...
# [ Info: Drawing frame 89 of 101...
# [ Info: Drawing frame 90 of 101...
# [ Info: Drawing frame 91 of 101...
# [ Info: Drawing frame 92 of 101...
# [ Info: Drawing frame 93 of 101...
# [ Info: Drawing frame 94 of 101...
# [ Info: Drawing frame 95 of 101...
# [ Info: Drawing frame 96 of 101...
# [ Info: Drawing frame 97 of 101...
# [ Info: Drawing frame 98 of 101...
# [ Info: Drawing frame 99 of 101...
# [ Info: Drawing frame 100 of 101...
# [ Info: Drawing frame 101 of 101...
# "cabbeling_2d.mp4"

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
